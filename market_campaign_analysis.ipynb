# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('superstore_data.csv')
df.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# Id                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
df.shape
# Out:
# (2240, 22)

# %%
df.isna().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.histplot(df['Income'], kde=True)
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
df[df['Income'].isna()]
# Out:
#          Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 134    8996        1957         PhD        Married     NaN        2         1
# 262    1994        1983  Graduation        Married     NaN        1         0
# 394    3769        1972         PhD       Together     NaN        1         0
# 449    5255        1986  Graduation         Single     NaN        1         0
# 525    8268        1961         PhD        Married     NaN        0         1
# 590   10629        1973    2n Cycle        Married     NaN        1         0
# 899   10475        1970      Master       Together     NaN        0         1
# 997    9235        1957  Graduation         Single     NaN        1         1
# 1096   4345        1964    2n Cycle         Single     NaN        1         1
# 1185   7187        1969      Master       Together     NaN        1         1
# 1213   8720        1978    2n Cycle       Together     NaN        0         0
# ...

# %% [markdown]
# A good approach might be to fill the missing income values as the average of the corresponding education level as opposed to a simple general average

# %%
df1 = df.copy()

# %%
def fill_nas(df):
    for i in df['Education'].unique():
        df[df['Education'] == i] = df[df['Education'] == i].fillna(df[df['Education'] == i]['Income'].mean())

# %%
fill_nas(df1)

# %%
df1.isna().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df1.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain]
# Index: []
#
# [0 rows x 22 columns]

# %%
df1.drop('Id',axis=1,inplace=True)

# %%
num_cols = []
cat_cols = []

# %%
for col in df1.columns:
    if df1[col].dtype == 'object':
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
for col in cat_cols[0:-1]:
    plt.figure(figsize=(20,3))
    sns.histplot(df1[col])

# %%
for col in num_cols[0:-2]:
    plt.figure(figsize=(20,3))
    sns.histplot(df1[col],kde=True)

# %%
dummy_cols = ['Response','Complain']

# %%
for index,col in enumerate(dummy_cols):
    plt.subplot(1,2,index+1)
    plt.tight_layout()
    sns.histplot(df1[col])

# %%
for col in num_cols:
    plt.figure(figsize=(20,5))
    sns.violinplot(x=df[col])

# %% [markdown]
# ### Correcting Date Column

# %%
import datetime

# %%
df1['Date'] = pd.to_datetime(df1['Dt_Customer'])

# %%
df1['Year'] = df1['Date'].dt.year
df1['Month'] = df1['Date'].dt.month
df1['Day'] = df1['Date'].dt.day

# %%
df1.drop(['Date','Dt_Customer'],axis=1,inplace=True)

# %%
df1.head(3)
# Out:
#    Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 0        1970  Graduation       Divorced  84835.0        0         0        0
# 1        1961  Graduation         Single  57091.0        0         0        0
# 2        1958  Graduation        Married  67267.0        0         1        0
#
#    MntWines  MntFruits  MntMeatProducts  ...  NumDealsPurchases  \
# 0       189        104              379  ...                  1
# 1       464          5               64  ...                  1
# 2       134         11               59  ...                  1
#
#    NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0                4                    4                  6                  1
# 1                7                    3                  7                  5
# 2                3                    2                  5                  2
#
#    Response  Complain  Year  Month  Day
# ...

# %%
plt.figure(figsize=(20,5))
sns.catplot(data=df1,x='Year_Birth',col='Response',kind='violin')

# %%
expenditure_cols = ['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']

# %%
def expenditure_scatter_graphs(df,column_name):
    fig, axes = plt.subplots(int(len(expenditure_cols)/2),2,figsize=(20,20))
    for index,col in enumerate(expenditure_cols):
        plt.subplot(int(len(expenditure_cols)/2),2,index+1)
        sns.scatterplot(data=df,x=column_name,y=col)
        plt.tight_layout()

# %%
expenditure_scatter_graphs(df1,'Year_Birth')

# %%
plt.figure(figsize=(20,5))
sns.catplot(data=df1,x='Education',col='Response',kind='count')

# %%
expenditure_scatter_graphs(df1,'Education')
